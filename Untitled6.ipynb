# %% [markdown]
# <a href="https://colab.research.google.com/github/timendonca/BANCO-DE-DADOS/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# Upload the file
uploaded = files.upload()

# Assuming the file is named '2024_OrcamentoDespesa.csv'
file_path = '2024_OrcamentoDespesa.csv'
# Specify the error_bad_lines parameter to skip bad lines or 'warn' to show warnings
df = pd.read_csv(file_path, encoding='latin-1', on_bad_lines='skip')
# or df = pd.read_csv(file_path, encoding='latin-1', on_bad_lines='warn')
# ... rest of your code ...

# Exibindo as primeiras linhas do dataset
print("Primeiras linhas do dataset:")
print(df.head())

# Verificando a estrutura dos dados
print("\nInformações gerais:")
print(df.info())

# Verificando o tamanho do dataset
print("\nFormato do dataset (linhas, colunas):")
print(df.shape)

# Exibindo o nome das colunas
print("\nNome das colunas:")
print(df.columns)

# Estatísticas descritivas
print("\nEstatísticas descritivas:")
print(df.describe())

# Verificando valores nulos
print("\nValores nulos por coluna:")
print(df.isnull().sum())

# Verificando valores duplicados
print("\nNúmero de registros duplicados:")
print(df.duplicated().sum())

# Tratando dados nulos
print("\nTratando dados nulos com mediana (se necessário):")
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    if df[column].isnull().sum() > 0:
        median_value = df[column].median()
        df[column].fillna(median_value, inplace=True)
        print(f"Coluna {column}: preenchida com mediana {median_value}")

# Removendo duplicatas
df.drop_duplicates(inplace=True)
print("\nDuplicatas removidas.")

# Estatísticas após limpeza
print("\nEstatísticas após limpeza:")
print(df.describe())
# Exibindo as primeiras linhas do dataset
print("Primeiras linhas do dataset:")
print(df.head())

# Verificando a estrutura dos dados
print("\nInformações gerais:")
print(df.info())

# Verificando o tamanho do dataset
print("\nFormato do dataset (linhas, colunas):")
print(df.shape)

# Exibindo o nome das colunas
print("\nNome das colunas:")
print(df.columns)

# Estatísticas descritivas
print("\nEstatísticas descritivas:")
print(df.describe())

# Verificando valores nulos
print("\nValores nulos por coluna:")
print(df.isnull().sum())

# Verificando valores duplicados
print("\nNúmero de registros duplicados:")
print(df.duplicated().sum())

# Tratando dados nulos
print("\nTratando dados nulos com mediana (se necessário):")
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    if df[column].isnull().sum() > 0:
        median_value = df[column].median()
        df[column].fillna(median_value, inplace=True)
        print(f"Coluna {column}: preenchida com mediana {median_value}")

# Removendo duplicatas
df.drop_duplicates(inplace=True)
print("\nDuplicatas removidas.")

# Estatísticas após limpeza
print("\nEstatísticas após limpeza:")
print(df.describe())
# Out:
#      <input type="file" id="files-f8766279-785c-4a0e-9ee0-bd8ad05f29dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8766279-785c-4a0e-9ee0-bd8ad05f29dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
